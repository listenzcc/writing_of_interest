# %%
import requests
from bs4 import BeautifulSoup

# %%
html_doc = """
<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title"><b>The Dormouse's story</b></p>

<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>
"""

soup = BeautifulSoup(html_doc)

print(soup.prettify())

print('\n\n'.join([e.__str__() for e in [
    soup.title,
    soup.title.name,
    soup.title.string,
    soup.title.parent.name,
    soup.p,
    soup.p['class'],
    soup.a,
    soup.find_all('a'),
    soup.find(id="link3"),
    ]]))
# Out:
# <html>
#  <head>
#   <title>
#    The Dormouse's story
#   </title>
#  </head>
#  <body>
#   <p class="title">
#    <b>
#     The Dormouse's story
#    </b>
#   </p>
#   <p class="story">
#    Once upon a time there were three little sisters; and their names were
#    <a class="sister" href="http://example.com/elsie" id="link1">
#     Elsie
#    </a>
#    ,
#    <a class="sister" href="http://example.com/lacie" id="link2">
#     Lacie
#    </a>
#    and
#    <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>
#    ;
# and they lived at the bottom of a well.
#   </p>
#   <p class="story">
#    ...
#   </p>
#  </body>
# </html>
# <title>The Dormouse's story</title>
#
# title
#
# The Dormouse's story
#
# head
#
# <p class="title"><b>The Dormouse's story</b></p>
#
# ['title']
#
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>
#
# ...

# %%
url = 'https://www.statlect.com/probability-distributions/'
url = 'https://www.statlect.com/'
resp = requests.get(url)
soup = BeautifulSoup(resp.text)
soup.prettify
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# <html>
# <head>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1.0" name="viewport"/>
# <link href="https://fonts.googleapis.com/css?family=Open+Sans:300,400,600,700,800" rel="stylesheet"/>
# <link href="/all.css" media="all and (min-width: 901px)" rel="stylesheet" type="text/css"/>
# <link href="/mobile.css" media="all and (max-width: 900px)" rel="stylesheet" type="text/css"/>
# <link href="/apple-touch-icon.png" rel="apple-touch-icon"/>
# <meta content="text/html;charset=utf-8" http-equiv="Content-Type"/>
# <title>Statlect, the digital textbook</title>
# <meta content="Hundreds of lectures on probability and statistics, with examples and solved exercises. Rigorous, but easy to understand. Ideal for self-study." name="description"/>
# <meta content="_ZevGCR6RvM3Ft3IJK7UySfciIAVjflZ-ntyNJmWtEY" name="google-site-verification"/>
# ...

# %%
spliter = ['.', '\n']

def strip(tag, spliter=spliter):
    # Get text and strip it
    s = tag.get_text().strip()
    # Regularize the spliter
    for sp in spliter:
        s = s.replace(sp, '\n')
    # Generate output list and return it
    return [e.strip() for e in s.split('\n') if e.strip()]

found = [strip(tag) for tag in soup.find_all()]

sentences = set()
for entry in found:
    for f in entry:
        sentences.add(f.lower())
sentences
# Out:
# {'a central limit theorem provides a set of conditions that are sufficient for the sample mean to have a normal distribution asymptotically (as the sample size increases)',
#  'a discrete distribution used to model the number of successes obtained by repeating several times an experiment that can have two outcomes, either success or failure',
#  'a gentle introduction to the concept of expected value, with an informal definition and more formal definitions based on the stieltjes and lebesgue integrals',
#  'a statistical test based on the comparison of two parameter estimates, a restricted one and an unrestricted one',
#  'a test that is often performed on parameters that have been estimated by maximum likelihood, based on a test statistics called the wald statistic',
#  'about',
#  'about statlect',
#  'asymptotic theory',
# ...

# %%
import pandas as pd

# %%
df = pd.DataFrame()
df['sentences'] = range(len(sentences))
df['sentences'] = sentences
df
# Out:
#                                              sentences
# 0    probability distributionsexplore this compendi...
# 1                                new and updated pages
# 2                                                index
# 3    the moment generating function is often used t...
# 4    wald testa test that is often performed on par...
# ..                                                 ...
# 113                     statlect, the digital textbook
# 114  poisson distributionthe poisson distribution i...
# 115  expected valuea gentle introduction to the con...
# 116  a gentle introduction to the concept of expect...
# 117                                      popular pages
#
# [118 rows x 1 columns]

# %%
def query(s, df=df, col='sentences'):
    return df[df.sentences.str.contains(s)]

query('probability')
# Out:
#                                              sentences
# 0    probability distributionsexplore this compendi...
# 3    the moment generating function is often used t...
# 7    fundamentals of probability theoryread a rigor...
# 12                         fundamentals of probability
# 15   bayes' rule is a formula that allows to comput...
# 22   maximum likelihoodmaximum likelihood is an est...
# 25                          convergence in probability
# 30   the poisson distribution is a discrete probabi...
# 34   read a rigorous yet accessible introduction to...
# 40   beta functionthe beta function is often employ...
# 44   maximum likelihood is an estimation method tha...
# 45   bayes' rulebayes' rule is a formula that allow...
# 46   statlect is a free digital textbook on probabi...
# 53        glossary of probability and statistics terms
# 54   learn about mathematical concepts that are fre...
# 55   the beta distribution is a continuous probabil...
# ...
